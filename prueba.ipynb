# %% [markdown]
# ### Cargada de datos de los diferentes excel

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as mp

excelTvDia1 = 'TvDia1.xlsx'
excelTvDia2 = 'TvDia2.xlsx'
excelTvDia3 = 'TvDia3.xlsx'


df_TvDia1 = pd.read_excel(excelTvDia1)
df_TvDia2 = pd.read_excel(excelTvDia2)
df_TvDia3 = pd.read_excel(excelTvDia3)

# %% [markdown]
# ### Gráficos

# %%
Fpdia1=df_TvDia1['Factor de Potencia']
Iddia1=df_TvDia1['ID']
Codia1=df_TvDia1['Corriente']
Voldia1=df_TvDia1['Voltaje']
Padia1=df_TvDia1['Potencia activa']

Fpdia2=df_TvDia2['Factor de Potencia']
Iddia2=df_TvDia2['ID']
Codia2=df_TvDia2['Corriente']
Voldia2=df_TvDia2['Voltaje']
Padia2=df_TvDia2['Potencia activa']

Fpdia3=df_TvDia3['Factor de Potencia']
Iddia3=df_TvDia3['ID']
Codia3=df_TvDia3['Corriente']
Voldia3=df_TvDia3['Voltaje']
Padia3=df_TvDia3['Potencia activa']



mp.plot(Iddia1,Padia1,Iddia2,Padia2,Iddia3,Padia3)
mp.legend(("Voldia1","Voldia2", "Voldia3"))
mp.ylabel('Voltaje')
mp.xlabel('Momento')


#mp.plot(IdNoteToshiva,FpNoteToshiva,IdNoteHp,FpNoteHp,IdNoteSamsung,FpNoteSamsung)
#mp.legend(("FpNoteToshiva","FpNoteHp","FpNoteSamsung"))
#mp.ylabel('Factor de Potencia')
#mp.xlabel('Momento')
mp.show()
